# %%
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib.pyplot as plt

from svgpathtools import svg2paths, svg2paths2, wsvg

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
paths, attributes = svg2paths('drawing_2.svg')

# %%
attributes
# Out:
# [{'d': 'm 235.58277,297.48918 0,-30.81175 m -0.051,30.81175 0,-31.63145 m 0,31.63145 0,-29.24953 m -0.0495,29.24953 0,-29.99395 m -0.0523,29.99395 0,-31.55681 m -0.0497,31.55681 0,-30.44049 m -0.051,30.44049 0,-26.1232 m -0.0529,26.1232 0,-30.51513 m -0.0503,30.51513 0,-31.25956 m 0,31.25956 0,-32.97103 m -0.0502,32.97103 0,-28.65503 m -0.0516,28.65503 0,-31.70608 m -0.0502,31.70608 0,-29.47344 m -0.0516,29.47344 0,-28.5051 m -0.051,28.5051 0,-30.66312 m -0.0516,30.66312 0,-29.84533 m 0,29.84533 0,-29.24953 m -0.0502,29.24953 0,-29.02691 m -0.0523,29.02691 0,-32.2266 m -0.0501,32.2266 0,-30.44049 m -0.051,30.44049 0,-31.63145 m -0.051,31.63145 0,-29.32289 m -0.051,29.32289 0,-28.43048 m 0,28.43048 0,-34.01336 m -0.0523,34.01336 0,-30.06796 m -0.0509,30.06796 0,-27.91059 m -0.0503,27.91059 0,-30.96102 m -0.051,30.96102 0,-29.24953 m -0.0509,29.24953 0,-27.91059 m -0.0516,27.91059 0,-29.99395 m 0,29.99395 0,-29.54614 m -0.051,29.54614 0,-30.51513 m -0.0516,30.51513 0,-30.06796 m -0.050
# ...

# %%
paths
# Out:
# [Path(Line(start=(235.58277+297.48918j), end=(235.58277+266.67742999999996j)),
#       Line(start=(235.53177000000002+297.48918j), end=(235.53177000000002+265.85772999999995j)),
#       Line(start=(235.53177000000002+297.4891799999999j), end=(235.53177000000002+268.2396499999999j)),
#       Line(start=(235.48227000000003+297.4891799999999j), end=(235.48227000000003+267.49522999999994j)),
#       Line(start=(235.42997000000003+297.4891799999999j), end=(235.42997000000003+265.93236999999993j)),
#       Line(start=(235.38027000000002+297.4891799999999j), end=(235.38027000000002+267.0486899999999j)),
#       Line(start=(235.32927000000004+297.4891799999999j), end=(235.32927000000004+271.3659799999999j)),
#       Line(start=(235.27637000000004+297.4891799999999j), end=(235.27637000000004+266.9740499999999j)),
#       Line(start=(235.22607000000005+297.4891799999999j), end=(235.22607000000005+266.2296199999999j)),
# ...

# %%
paths, attributes, svg_attributes = svg2paths2('drawing_2.svg')

# %%
paths
# Out:
# [Path(Line(start=(235.58277+297.48918j), end=(235.58277+266.67742999999996j)),
#       Line(start=(235.53177000000002+297.48918j), end=(235.53177000000002+265.85772999999995j)),
#       Line(start=(235.53177000000002+297.4891799999999j), end=(235.53177000000002+268.2396499999999j)),
#       Line(start=(235.48227000000003+297.4891799999999j), end=(235.48227000000003+267.49522999999994j)),
#       Line(start=(235.42997000000003+297.4891799999999j), end=(235.42997000000003+265.93236999999993j)),
#       Line(start=(235.38027000000002+297.4891799999999j), end=(235.38027000000002+267.0486899999999j)),
#       Line(start=(235.32927000000004+297.4891799999999j), end=(235.32927000000004+271.3659799999999j)),
#       Line(start=(235.27637000000004+297.4891799999999j), end=(235.27637000000004+266.9740499999999j)),
#       Line(start=(235.22607000000005+297.4891799999999j), end=(235.22607000000005+266.2296199999999j)),
# ...

# %%
attributes
# Out:
# [{'d': 'm 235.58277,297.48918 0,-30.81175 m -0.051,30.81175 0,-31.63145 m 0,31.63145 0,-29.24953 m -0.0495,29.24953 0,-29.99395 m -0.0523,29.99395 0,-31.55681 m -0.0497,31.55681 0,-30.44049 m -0.051,30.44049 0,-26.1232 m -0.0529,26.1232 0,-30.51513 m -0.0503,30.51513 0,-31.25956 m 0,31.25956 0,-32.97103 m -0.0502,32.97103 0,-28.65503 m -0.0516,28.65503 0,-31.70608 m -0.0502,31.70608 0,-29.47344 m -0.0516,29.47344 0,-28.5051 m -0.051,28.5051 0,-30.66312 m -0.0516,30.66312 0,-29.84533 m 0,29.84533 0,-29.24953 m -0.0502,29.24953 0,-29.02691 m -0.0523,29.02691 0,-32.2266 m -0.0501,32.2266 0,-30.44049 m -0.051,30.44049 0,-31.63145 m -0.051,31.63145 0,-29.32289 m -0.051,29.32289 0,-28.43048 m 0,28.43048 0,-34.01336 m -0.0523,34.01336 0,-30.06796 m -0.0509,30.06796 0,-27.91059 m -0.0503,27.91059 0,-30.96102 m -0.051,30.96102 0,-29.24953 m -0.0509,29.24953 0,-27.91059 m -0.0516,27.91059 0,-29.99395 m 0,29.99395 0,-29.54614 m -0.051,29.54614 0,-30.51513 m -0.0516,30.51513 0,-30.06796 m -0.050
# ...

# %%
svg_attributes
# Out:
# {'height': '495.78973',
#  'id': 'svg5189',
#  'version': '1.1',
#  'viewBox': '0 0 210.92506 139.92288',
#  'width': '747.37225',
#  'xmlns': 'http://www.w3.org/2000/svg',
#  'xmlns:cc': 'http://creativecommons.org/ns#',
#  'xmlns:dc': 'http://purl.org/dc/elements/1.1/',
#  'xmlns:rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#  'xmlns:svg': 'http://www.w3.org/2000/svg'}

# %%
wsvg(paths, attributes=attributes, filename='output1.svg')

# %%
a = np.array((paths))
a
# Out:
# array([[[ 235.582770+297.48918j,  235.582770+266.67743j],
#         [ 235.531770+297.48918j,  235.531770+265.85773j],
#         [ 235.531770+297.48918j,  235.531770+268.23965j],
#         ...,
#         [  25.240068+297.48918j,   25.240068+279.85003j],
#         [  25.189168+297.48918j,   25.189168+280.89234j],
#         [  25.137568+297.48918j,   25.137568+279.55212j]]])

# %%
p1 = a[0][0]
p2 = a[0][1]

# %%
plt.scatter(x=[p1[0].real, p1[1].real], y=[p1[0].imag, p1[1].imag])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-8f4173cc78c8> in <module>()
# ----> 1 plt.scatter(p1)
#
# TypeError: scatter() missing 1 required positional argument: 'y'
